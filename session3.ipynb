# %%
a = 20
b = 40
print(a+b)
# Out:
# 60

# %%
a = int(input("adad ra vered konid"))
a*2
# Out:
# 40

# %%
adad = int(input())
if adad == 2:
    print("adad barabar 2 hast")
else:
    print("adad barabar 2 nist")
# Out:
# adad barabar 2 nist

# %%
adad = int(input())
if adad%2==0 and adad%5==0 and adad%13==0:
    print("adad bar 5 va 2 are")
else:
    print("fard")
# Out:
# fard
